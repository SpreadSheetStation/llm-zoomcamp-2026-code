# %%
print("Hello World")
# Out:
# Hello World

# %%
from fp_ingest import load_qa_kb
import json

documents = load_qa_kb()

# Print the first record in a readable format
print(json.dumps(documents[0], indent=2))
# Out:
# {
#   "qa_id": "qa_001",
#   "doc_id": "doc_001",
#   "question": "What is the dancing plague of 1518?",
#   "answer": "The dancing plague of 1518, or dance epidemic of 1518, was a case of dancing mania that occurred in Strasbourg"
# }

# %%
from dotenv import load_dotenv
load_dotenv()

from fp_ingest import load_qa_kb, build_index
from fp_rag_helper import RAGBase
from openai import OpenAI

# Fixed: Use the correct function name
documents = load_qa_kb()
index = build_index(documents)

openai_client = OpenAI()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

# Optional: Change this to a question about the Dancing Plague since that's your data
answer = assistant.rag("What caused the dancing plague of 1518?")
print(answer)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[6], line 12
#       8 # Fixed: Use the correct function name
#       9 documents = load_qa_kb()
#      10 index = build_index(documents)
#      11
# ---> 12 openai_client = OpenAI()
#      13
#      14 assistant = RAGBase(
#      15     index=index,
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/_client.py:230, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     220 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     222 if (
#     223     provider_runtime is None
#     224     and _enforce_credentials
#    (...)    228     and self.admin_api_key is None
#     229 ):
# --> 230     raise OpenAIError(
#     231         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     232     )
#     234 if organization is None and provider_runtime is None:
#     235     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
